# %%
import psutil
import cv2
from ultralytics import YOLO


# Load a pretrained YOLO model (recommended for training)
model = YOLO('yolov8n-pose.pt')

# %%
#cpu and mem times start
cpu_start = psutil.cpu_percent(interval=None)
memory_start = psutil.virtual_memory().used

# Run inference on video
result = model("pushupseries.mp4", show=True, save=True)  
#save - saves .mp4s of runs 
#show - plots keypoints in real time while streaming video
# add stream=True to save memory (video is processed in chunks)

#cpu and mem times end
cpu_end = psutil.cpu_percent(interval=None)
memory_end = psutil.virtual_memory().used


cpu_usage = cpu_end - cpu_start
memory_usage = memory_end - memory_start
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/10190) /home/rtu/Documents/Perf_metrics_test/pushupseries.mp4: 384x640 1 person, 218.8ms
# video 1/1 (frame 2/10190) /home/rtu/Documents/Perf_metrics_test/pushupseries.mp4: 384x640 1 person, 6.9ms
# video 1/1 (frame 3/10190) /home/rtu/Documents/Perf_metrics_test/pushupseries.mp4: 384x640 1 person, 6.4ms
# video 1/1 (frame 4/10190) /home/rtu/Documents/Perf_metrics_test/pushupseries.mp4: 384x640 1 person, 8.6ms
# ...

# %%
# Resource usage results
print(f"CPU Usage: {cpu_usage}%")
print(f"Memory Usage: {memory_usage / (1024 ** 2)} MB")
# Out:
# CPU Usage: 16.4%
# Memory Usage: 7438.4453125 MB
